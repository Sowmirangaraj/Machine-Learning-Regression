# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age','bmi','children','sex_male', 'smoker_yes']]

# %%
dep=dataset[['charges']]

# %%
## criterion=“squared_error”, “friedman_mse”, “absolute_error”, “poisson”}, default=”squared_error”
## splitter=“best”, “random”, default=”best”
## max_features="sqrt", "log2"

# %%
##(criterion="squared_error",splitter="best"

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['absolute_error', 'poisson', 'friedman_mse', 'squared_error'],
              'max_features': ['sqrt','log2'],
              'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'poisson',
#                                        'friedman_mse', 'squared_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.029386      0.000947         0.005415        0.000669
# 1        0.029615      0.009235         0.004440        0.000642
# 2        0.031251      0.002738         0.004758        0.001661
# 3        0.023137      0.001831         0.004318        0.000773
# 4        0.011631      0.001847         0.004523        0.001646
# 5        0.010452      0.001222         0.004935        0.000921
# 6        0.011995      0.000739         0.004555        0.000703
# 7        0.009053      0.001526         0.003515        0.001571
# 8        0.008884      0.001248         0.004133        0.000212
# 9        0.006856      0.000756         0.003991        0.000736
# 10       0.007800      0.000360         0.004348        0.001059
# 11       0.007445      0.000792         0.003650        0.000309
# 12       0.006496      0.001033         0.004235        0.000712
# 13       0.006873      0.001136         0.003646        0.000468
# 14       0.006358      0.002344         0.004469        0.001675
# 15       0.006835      0.001536         0.002812        0.000734
#
#    param_criterion param_max_features param_splitter  \
# 0   absolute_error               sqrt           best
# 1   absolute_error               sqrt         random
# 2   absolute_error               log2           best
# 3   absolute_error               log2         random
# 4          poisson               sqrt           best
# 5          poisson               sqrt         random
# 6          poisson               log2           best
# 7          poisson               log2         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12   squared_error               sqrt           best
# 13   squared_error               sqrt         random
# 14   squared_error               log2           best
# 15   squared_error               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'absolute_error', 'max_features'...           0.780285
# 1   {'criterion': 'absolute_error', 'max_features'...           0.721097
# 2   {'criterion': 'absolute_error', 'max_features'...           0.745748
# 3   {'criterion': 'absolute_error', 'max_features'...           0.696183
# 4   {'criterion': 'poisson', 'max_features': 'sqrt...           0.729128
# 5   {'criterion': 'poisson', 'max_features': 'sqrt...           0.685799
# 6   {'criterion': 'poisson', 'max_features': 'log2...           0.549193
# 7   {'criterion': 'poisson', 'max_features': 'log2...           0.664915
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.747013
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.673608
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.664630
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.659661
# 12  {'criterion': 'squared_error', 'max_features':...           0.658901
# 13  {'criterion': 'squared_error', 'max_features':...           0.695747
# 14  {'criterion': 'squared_error', 'max_features':...           0.718907
# 15  {'criterion': 'squared_error', 'max_features':...           0.655436
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.600723           0.691622           0.728309
# 1            0.538047           0.719309           0.622989
# 2            0.610910           0.690200           0.700411
# 3            0.651227           0.741459           0.698898
# 4            0.643639           0.542350           0.664853
# 5            0.573270           0.632876           0.678373
# 6            0.644124           0.770277           0.715101
# 7            0.436718           0.692301           0.681935
# 8            0.561052           0.728193           0.692178
# 9            0.682267           0.648080           0.688192
# 10           0.617049           0.474602           0.688845
# 11           0.537295           0.661817           0.640501
# 12           0.641892           0.599264           0.680682
# 13           0.643943           0.672743           0.647247
# 14           0.581459           0.745532           0.686873
# 15           0.569522           0.740965           0.641186
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.700070         0.700202        0.058605                1
# 1            0.701918         0.660672        0.071060                9
# 2            0.681161         0.685686        0.043489                2
# 3            0.574324         0.672418        0.056752                7
# 4            0.660469         0.648088        0.060336               11
# 5            0.640858         0.642235        0.040124               12
# 6            0.718924         0.679524        0.076542                6
# 7            0.531901         0.601554        0.100730               16
# 8            0.696417         0.684971        0.065201                3
# 9            0.707852         0.680000        0.019533                5
# 10           0.687682         0.626562        0.080307               15
# 11           0.642867         0.628428        0.046368               14
# 12           0.725367         0.661221        0.041740                8
# 13           0.522811         0.636498        0.059866               13
# 14           0.675961         0.681746        0.055798                4
# 15           0.648204         0.651063        0.054509               10

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 28
# BMI: 33.77
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[44585.45587]
# C:\anaconda 3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
