# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age','bmi','children','sex_male', 'smoker_yes']]

# %%
dep=dataset[['charges']]

# %%
from sklearn.svm import SVR

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'kernel':['linear','rbf','poly','sigmoid'],
              'C':[10,100,1000,2000,3000]}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\anaconda 3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.134566      0.005257         0.019784        0.001152       10
# 1        0.127835      0.004519         0.050036        0.002099       10
# 2        0.123334      0.006726         0.021792        0.002570       10
# 3        0.160948      0.012989         0.030475        0.001667       10
# 4        0.248470      0.008497         0.021789        0.002405      100
# 5        0.127081      0.003634         0.053143        0.000758      100
# 6        0.126784      0.006312         0.019397        0.000795      100
# 7        0.140929      0.002094         0.029018        0.000795      100
# 8        0.789633      0.053673         0.018374        0.000504     1000
# 9        0.125824      0.005905         0.051908        0.001241     1000
# 10       0.159225      0.006791         0.020400        0.001239     1000
# 11       0.143517      0.005837         0.037545        0.006848     1000
# 12       1.333258      0.099269         0.019757        0.001564     2000
# 13       0.133713      0.003730         0.052205        0.001034     2000
# 14       0.177517      0.005944         0.020353        0.001365     2000
# 15       0.136804      0.002878         0.029572        0.000684     2000
# 16       2.067277      0.338333         0.011157        0.002660     3000
# 17       0.135176      0.003890         0.051124        0.002117     3000
# 18       0.211118      0.016883         0.019370        0.000866     3000
# 19       0.131226      0.003912         0.028553        0.001067     3000
#
#    param_kernel                            params  split0_test_score  \
# 0        linear     {'C': 10, 'kernel': 'linear'}          -0.018943
# 1           rbf        {'C': 10, 'kernel': 'rbf'}          -0.110409
# 2          poly       {'C': 10, 'kernel': 'poly'}          -0.125153
# 3       sigmoid    {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 4        linear    {'C': 100, 'kernel': 'linear'}           0.559313
# 5           rbf       {'C': 100, 'kernel': 'rbf'}          -0.160182
# 6          poly      {'C': 100, 'kernel': 'poly'}          -0.132885
# 7       sigmoid   {'C': 100, 'kernel': 'sigmoid'}          -0.142455
# 8        linear   {'C': 1000, 'kernel': 'linear'}           0.736398
# 9           rbf      {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 10         poly     {'C': 1000, 'kernel': 'poly'}          -0.080527
# 11      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}          -2.043140
# 12       linear   {'C': 2000, 'kernel': 'linear'}           0.682349
# 13          rbf      {'C': 2000, 'kernel': 'rbf'}          -0.143510
# 14         poly     {'C': 2000, 'kernel': 'poly'}          -0.020567
# 15      sigmoid  {'C': 2000, 'kernel': 'sigmoid'}          -7.209317
# 16       linear   {'C': 3000, 'kernel': 'linear'}           0.677778
# 17          rbf      {'C': 3000, 'kernel': 'rbf'}          -0.128958
# 18         poly     {'C': 3000, 'kernel': 'poly'}           0.037700
# 19      sigmoid  {'C': 3000, 'kernel': 'sigmoid'}         -15.561853
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.029886           0.022167           0.003112
# 1           -0.097459          -0.074488          -0.099597
# 2           -0.081505          -0.111907          -0.131602
# 3           -0.119312          -0.085214          -0.108210
# 4            0.521798           0.547691           0.538805
# 5           -0.107253          -0.123430          -0.137753
# 6           -0.082461          -0.129220          -0.139962
# 7           -0.160831          -0.117544          -0.137984
# 8            0.675162           0.680002           0.699377
# 9           -0.098267          -0.123724          -0.137137
# 10          -0.028469          -0.073376          -0.086611
# 11          -2.686121          -2.194563          -2.210858
# 12           0.630642           0.750714           0.646368
# 13          -0.087595          -0.113312          -0.128591
# 14           0.035685          -0.011468          -0.024587
# 15          -9.282940          -7.776578          -7.745074
# 16           0.626814           0.732806           0.633479
# 17          -0.075578          -0.100199          -0.116051
# 18           0.098496           0.049291           0.035615
# 19         -20.498908         -17.095474         -16.750877
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.066653        -0.006086        0.034672                6
# 1           -0.124428        -0.101276        0.016459                9
# 2           -0.179328        -0.125899        0.031794               12
# 3           -0.108716        -0.107639        0.012029               10
# 4            0.508518         0.535225        0.018122                4
# 5           -0.209551        -0.147634        0.035511               17
# 6           -0.189219        -0.134749        0.033948               14
# 7           -0.130402        -0.137843        0.014263               15
# 8            0.677952         0.693778        0.022955                1
# 9           -0.206405        -0.144193        0.036262               16
# 10          -0.134493        -0.080695        0.033795                8
# 11          -1.942521        -2.215441        0.255409               18
# 12           0.722261         0.686467        0.045056                2
# 13          -0.193992        -0.133400        0.035492               13
# 14          -0.076360        -0.019459        0.035693                7
# 15          -6.891719        -7.781126        0.821557               19
# 16           0.698692         0.673914        0.039876                3
# 17          -0.179304        -0.120018        0.034578               11
# 18          -0.020924         0.040035        0.038064                5
# 19         -15.012168       -16.983856        1.914783               20

# %%
# age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# BMI: 28
# Children: 33.77
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[41699.80923337]
# C:\anaconda 3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
