# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age','bmi','children','sex_male', 'smoker_yes']]

# %%
dep=dataset[['charges']]

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators':[10, 50, 100, 500],
              'learning_rate':[0.0001, 0.001, 0.01, 0.1, 1.0]}         
grid = GridSearchCV(AdaBoostRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\anaconda 3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=AdaBoostRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.0001, 0.001, 0.01, 0.1, 1.0],
#                          'n_estimators': [10, 50, 100, 500]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.035133      0.005835         0.005223        0.000891
# 1        0.131352      0.009944         0.010602        0.000994
# 2        0.243575      0.002907         0.017904        0.001769
# 3        1.189419      0.013627         0.080421        0.003868
# 4        0.032665      0.006875         0.005479        0.000922
# 5        0.124754      0.004777         0.010414        0.001115
# 6        0.238634      0.006660         0.016970        0.001016
# 7        1.174426      0.013693         0.079239        0.002593
# 8        0.030747      0.004512         0.004001        0.000003
# 9        0.121571      0.007076         0.010109        0.000737
# 10       0.243568      0.009099         0.016067        0.000401
# 11       1.064787      0.014298         0.051690        0.002959
# 12       0.029108      0.001731         0.004226        0.000404
# 13       0.124795      0.009569         0.010020        0.000244
# 14       0.178330      0.016487         0.015325        0.002449
# 15       0.167159      0.007986         0.012571        0.001840
# 16       0.029511      0.002575         0.004384        0.000697
# 17       0.028442      0.006982         0.005277        0.001609
# 18       0.029772      0.005849         0.004863        0.001165
# 19       0.033898      0.010494         0.003729        0.002005
#
#     param_learning_rate  param_n_estimators  \
# 0                0.0001                  10
# 1                0.0001                  50
# 2                0.0001                 100
# 3                0.0001                 500
# 4                0.0010                  10
# 5                0.0010                  50
# 6                0.0010                 100
# 7                0.0010                 500
# 8                0.0100                  10
# 9                0.0100                  50
# 10               0.0100                 100
# 11               0.0100                 500
# 12               0.1000                  10
# 13               0.1000                  50
# 14               0.1000                 100
# 15               0.1000                 500
# 16               1.0000                  10
# 17               1.0000                  50
# 18               1.0000                 100
# 19               1.0000                 500
#
#                                             params  split0_test_score  \
# 0    {'learning_rate': 0.0001, 'n_estimators': 10}           0.873359
# 1    {'learning_rate': 0.0001, 'n_estimators': 50}           0.877104
# 2   {'learning_rate': 0.0001, 'n_estimators': 100}           0.874143
# 3   {'learning_rate': 0.0001, 'n_estimators': 500}           0.875654
# 4     {'learning_rate': 0.001, 'n_estimators': 10}           0.874417
# 5     {'learning_rate': 0.001, 'n_estimators': 50}           0.875930
# 6    {'learning_rate': 0.001, 'n_estimators': 100}           0.875411
# 7    {'learning_rate': 0.001, 'n_estimators': 500}           0.875153
# 8      {'learning_rate': 0.01, 'n_estimators': 10}           0.878839
# 9      {'learning_rate': 0.01, 'n_estimators': 50}           0.870185
# 10    {'learning_rate': 0.01, 'n_estimators': 100}           0.872058
# 11    {'learning_rate': 0.01, 'n_estimators': 500}           0.849978
# 12      {'learning_rate': 0.1, 'n_estimators': 10}           0.874276
# 13      {'learning_rate': 0.1, 'n_estimators': 50}           0.849559
# 14     {'learning_rate': 0.1, 'n_estimators': 100}           0.841995
# 15     {'learning_rate': 0.1, 'n_estimators': 500}           0.838626
# 16      {'learning_rate': 1.0, 'n_estimators': 10}           0.828668
# 17      {'learning_rate': 1.0, 'n_estimators': 50}           0.801767
# 18     {'learning_rate': 1.0, 'n_estimators': 100}           0.819214
# 19     {'learning_rate': 1.0, 'n_estimators': 500}           0.777517
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.800517           0.880923           0.829427
# 1            0.792402           0.880684           0.829342
# 2            0.794298           0.882825           0.829332
# 3            0.791923           0.881967           0.829501
# 4            0.785379           0.881459           0.829830
# 5            0.794737           0.880810           0.828465
# 6            0.793630           0.881312           0.829335
# 7            0.797269           0.878803           0.831223
# 8            0.780828           0.878804           0.831415
# 9            0.795845           0.877860           0.829176
# 10           0.796902           0.876216           0.830057
# 11           0.790593           0.849510           0.818758
# 12           0.793212           0.873034           0.826895
# 13           0.792580           0.849186           0.816255
# 14           0.785095           0.851806           0.813114
# 15           0.784954           0.844183           0.813765
# 16           0.793643           0.812341           0.814718
# 17           0.779802           0.837426           0.819360
# 18           0.788918           0.831346           0.808118
# 19           0.777178           0.815161           0.806569
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.853798         0.847605        0.029528                8
# 1            0.861276         0.848162        0.033259                6
# 2            0.862535         0.848627        0.032674                2
# 3            0.863017         0.848412        0.033556                5
# 4            0.864569         0.847131        0.035608               10
# 5            0.862632         0.848515        0.032520                3
# 6            0.862402         0.848418        0.032778                4
# 7            0.864258         0.849342        0.030973                1
# 8            0.861684         0.846314        0.037041               12
# 9            0.863094         0.847232        0.030604                9
# 10           0.863197         0.847686        0.030128                7
# 11           0.843502         0.830468        0.022979               14
# 12           0.865291         0.846542        0.031789               11
# 13           0.848146         0.831145        0.023076               13
# 14           0.831920         0.824786        0.023617               15
# 15           0.839198         0.824145        0.022278               16
# 16           0.839352         0.817744        0.015527               17
# 17           0.832475         0.814166        0.021156               19
# 18           0.830618         0.815643        0.015839               18
# 19           0.833561         0.801997        0.021935               20

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 28
# BMI: 33.77
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[38508.27031126]
# C:\anaconda 3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
