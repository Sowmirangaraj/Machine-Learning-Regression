# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xg

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age','bmi','children','sex_male', 'smoker_yes']]

# %%
dep=dataset[['charges']]

# %%
from xgboost import XGBRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators':[10, 50, 100, 500],
              'learning_rate':[ 0.01, 0.1, 0.3],
              'max_depth': [3, 5, 7], 
              "min_child_weight": [ 1, 3, 5],
              "colsample_bytree":[ 0.3, 0.4]}
                     
grid = GridSearchCV(XGBRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bi...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.3, 0.4],
#                          'learning_rate': [0.01, 0.1, 0.3],
#                          'max_depth': [3, 5, 7], 'min_child_weight': [1, 3, 5],
#                          'n_estimators': [10, 50, 100, 500]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         1.832251      0.095557         0.007834        0.000919
# 1         1.792262      0.035689         0.007856        0.001033
# 2         0.717385      0.833344         0.008255        0.001448
# 3         0.152999      0.001716         0.009679        0.001370
# 4         0.016652      0.001103         0.007607        0.000571
# ..             ...           ...              ...             ...
# 211       0.228806      0.004078         0.011762        0.000608
# 212       0.016659      0.001087         0.006034        0.000094
# 213       0.031243      0.001877         0.006847        0.001096
# 214       0.054532      0.002698         0.006917        0.000695
# 215       0.187895      0.016259         0.007995        0.003592
#
#      param_colsample_bytree  param_learning_rate  param_max_depth  \
# 0                       0.3                 0.01                3
# 1                       0.3                 0.01                3
# 2                       0.3                 0.01                3
# 3                       0.3                 0.01                3
# 4                       0.3                 0.01                3
# ..                      ...                  ...              ...
# 211                     0.4                 0.30                7
# 212                     0.4                 0.30                7
# 213                     0.4                 0.30                7
# 214                     0.4                 0.30                7
# 215                     0.4                 0.30                7
#
#      param_min_child_weight  param_n_estimators  \
# 0                         1                  10
# 1                         1                  50
# 2                         1                 100
# 3                         1                 500
# 4                         3                  10
# ..                      ...                 ...
# 211                       3                 500
# 212                       5                  10
# 213                       5                  50
# 214                       5                 100
# 215                       5                 500
#
#                                                 params  split0_test_score  \
# 0    {'colsample_bytree': 0.3, 'learning_rate': 0.0...           0.041609
# 1    {'colsample_bytree': 0.3, 'learning_rate': 0.0...           0.120920
# 2    {'colsample_bytree': 0.3, 'learning_rate': 0.0...           0.244627
# 3    {'colsample_bytree': 0.3, 'learning_rate': 0.0...           0.622669
# 4    {'colsample_bytree': 0.3, 'learning_rate': 0.0...           0.041609
# ..                                                 ...                ...
# 211  {'colsample_bytree': 0.4, 'learning_rate': 0.3...           0.737443
# 212  {'colsample_bytree': 0.4, 'learning_rate': 0.3...           0.634875
# 213  {'colsample_bytree': 0.4, 'learning_rate': 0.3...           0.755466
# 214  {'colsample_bytree': 0.4, 'learning_rate': 0.3...           0.785791
# 215  {'colsample_bytree': 0.4, 'learning_rate': 0.3...           0.750748
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.040968           0.037179           0.040908
# 1             0.119952           0.106701           0.116070
# 2             0.238945           0.218844           0.234980
# 3             0.604791           0.580637           0.605543
# 4             0.040968           0.037179           0.040908
# ..                 ...                ...                ...
# 211           0.659170           0.761465           0.739326
# 212           0.616569           0.595554           0.656073
# 213           0.696669           0.746220           0.754805
# 214           0.716576           0.797188           0.776922
# 215           0.674408           0.774099           0.760457
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.041858         0.040505        0.001702              208
# 1             0.118175         0.116363        0.005106              190
# 2             0.241312         0.235742        0.009015              181
# 3             0.619731         0.606674        0.014893              125
# 4             0.041858         0.040505        0.001702              208
# ..                 ...              ...             ...              ...
# 211           0.733072         0.726095        0.034878               66
# 212           0.657190         0.632052        0.023617              118
# 213           0.754015         0.741435        0.022631               55
# 214           0.776841         0.770664        0.028054               43
# 215           0.746745         0.741291        0.034745               56
#
# [216 rows x 18 columns]

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 28
# BMI: 33.77
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[36782.42]
